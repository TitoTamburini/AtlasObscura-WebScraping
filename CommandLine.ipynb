# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ADM/Homework3
# Out:
# /content/drive/MyDrive/ADM/Homework3

# %% [markdown]
# #i)

# %%
! cut -f 8 merged.tsv | grep -c 'Italy\s'
# Out:
# 209

# %%
! cut -f 8 merged.tsv | grep -c 'Spain\s'
# Out:
# 92

# %%
! cut -f 8 merged.tsv | grep -c 'France\s'
# Out:
# 203

# %%
! cut -f 8 merged.tsv | grep -c 'England'
# Out:
# 367

# %%
! cut -f 8 merged.tsv | grep -c 'United States'
# Out:
# 4615

# %% [markdown]
# #ii)

# %%
! cut -f 3,8 merged.tsv | grep 'Italy' | awk '{ total += $0 } END { print total/NR }'
# Out:
# 384.448

# %%
! cut -f 3,8 merged.tsv | grep 'Spain' | awk '{ total += $0 } END { print total/NR }'
# Out:
# 446.598

# %%
! cut -f 3,8 merged.tsv | grep 'France' | awk '{ total += $0 } END { print total/NR }'
# Out:
# 426.383

# %%
! cut -f 3,8 merged.tsv | grep 'England' | awk '{ total += $0 } END { print total/NR }'
# Out:
# 476.725

# %%
! cut -f 3,8 merged.tsv | grep 'United States' | awk '{ total += $0 } END { print total/NR }'
# Out:
# 437.772

# %% [markdown]
# #iii)

# %%
! cut -f 3,8 merged.tsv | grep 'Italy' | awk '{ total += $0 } END {print total}'
# Out:
# 80734

# %%
! cut -f 3,8 merged.tsv | grep 'Spain' | awk '{ total += $0 } END {print total}'
# Out:
# 41087

# %%
! cut -f 3,8 merged.tsv | grep 'France' | awk '{ total += $0 } END {print total}'
# Out:
# 87835

# %%
! cut -f 3,8 merged.tsv | grep 'England' | awk '{ total += $0 } END {print total}'
# Out:
# 174958

# %%
! cut -f 3,8 merged.tsv | grep 'United States' | awk '{ total += $0 } END {print total}'
# Out:
# 2020318
